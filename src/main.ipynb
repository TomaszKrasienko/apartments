# %%
from src.scrapping.OtodomScrapper import OtoDomScrapper

# %%
otodom_scrapper: OtoDomScrapper = OtoDomScrapper()
otodom_scrapper.execute()
# Out:
# Going to page 1
# Last page number: 586
# Gets data from advertisement: 1. Blisko centrum, do dwupokojowej aranżacji.
# Gets data from advertisement: 2. Mieszkanie z garażem i schowkiem, Wawer
# Gets data from advertisement: 3. Mieszkanie 44,3m2 Białołęka Pasłęcka
# Gets data from advertisement: 4. BEZPOŚREDNIO 2-pokojowe, stan deweloperski, garaż
# Gets data from advertisement: 5. 2-pok w cichym, skomunikowanym punkcie Ochoty
# Gets data from advertisement: 6. Kompaktowe Mieszkanko Do Remontu
# Gets data from advertisement: 7. Do sprzedania 3 pokoje na Ursynowie metro Kabaty
# Gets data from advertisement: 8. ✅Zobacz>>Ustawne 4 pokoje przy metrze Bródno
# Gets data from advertisement: 9. ✅Sprawdź>>> ustawne 3 pokojowe mieszkanie
# Gets data from advertisement: 10. QBIK dwupoziomowy apartament z widokiem na zieleń
# Gets data from advertisement: 11. 2 pokoje, po remoncie, metro, Ursynów, BEZPOŚREDNI
# Gets data from advertisement: 12. Apartament | Umeblowany | Klimatyzacja
# ...
